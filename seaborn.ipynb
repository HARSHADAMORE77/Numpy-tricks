# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSHADAMORE77/Numpy-tricks/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the tips dataset
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Scatter plot
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Total Bill vs Tip")
plt.show()

# %%
# Line plot
sns.lineplot(x="total_bill", y="tip", data=tips)
plt.title("Total Bill vs Tip (Line Plot)")
plt.show()

# %%
# Bar plot
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Total Bill by Day")
plt.show()

# %%
# Histogram
sns.histplot(tips["total_bill"], kde=True)
plt.title("Distribution of Total Bill")
plt.show()

# %%
# Box plot
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("Total Bill by Day (Box Plot)")
plt.show()

# %%
# Violin plot
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title("Total Bill by Day (Violin Plot)")
plt.show()

# %%
# Pair plot
sns.pairplot(tips, hue="sex")
plt.show()

# %%
# Correlation heatmap

# %%
# Facet grid
g = sns.FacetGrid(tips, col="time", row="smoker")
g.map(sns.scatterplot, "total_bill", "tip")
plt.show()

# %%
# Customizing a scatter plot
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="time", style="smoker", size="size")
plt.title("Customized Scatter Plot")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.legend(title="Time", loc="upper left")
plt.show()
